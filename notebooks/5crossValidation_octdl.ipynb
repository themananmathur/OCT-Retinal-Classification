# %%
# DenseNet - OCTDL - 5CV
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Disable GPU if needed
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Enable Mixed Precision for Faster Training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Paths
dataset_base_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/dataset split/OCTDL_Splits"
logs_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/training"
models_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models"
results_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/results"

# Hyperparameters
image_size = 224
batch_size = 32
epochs = 50
num_classes = 7

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    zoom_range=0.3,
    shear_range=0.2
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Prepare results storage
all_results = []

for i in range(1, 6):
    print(f"\n========== Training on Fold {i} ==========")

    set_path = os.path.join(dataset_base_path, f"OCTDL_Set_{i}")
    train_dir, val_dir, test_dir = [os.path.join(set_path, x) for x in ["Train", "Validation", "Test"]]

    # Load datasets
    train_data = train_datagen.flow_from_directory(train_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical')
    val_data = val_test_datagen.flow_from_directory(val_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical')
    test_data = val_test_datagen.flow_from_directory(test_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical', shuffle=False)

    # Compute Class Weights
    labels = train_data.classes
    unique_classes = np.unique(labels)
    class_weights = compute_class_weight('balanced', classes=unique_classes, y=labels)
    class_weight_dict = {i: weight for i, weight in zip(unique_classes, class_weights)}

    # Load Pretrained DenseNet
    base_model = DenseNet121(weights="imagenet", include_top=False, input_shape=(image_size, image_size, 3))

    # Freeze all but top 50 layers
    for layer in base_model.layers[:-50]:
        layer.trainable = False
    for layer in base_model.layers[-15:]:
        layer.trainable = True

    # Build model
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        Dropout(0.5),
        Dense(num_classes, activation="softmax", dtype='float32')  # Match precision policy
    ])

    # Compile model with label smoothing
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=CategoricalCrossentropy(label_smoothing=0.1),
        metrics=["accuracy"]
    )

    # Callbacks
    model_save_path = os.path.join(models_path, f"denseNet_OCTDL_best_fold_{i}.keras")
    callbacks = [
        ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, verbose=1),
        EarlyStopping(monitor='val_accuracy', patience=8, verbose=1, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_accuracy', factor=0.2, patience=4, verbose=1),
        CSVLogger(os.path.join(logs_path, f"denseNet_OCTDL_fold_{i}.csv"), append=True)
    ]

    # Train
    model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        class_weight=class_weight_dict,
        callbacks=callbacks
    )

    # Evaluate on Test Set
    test_loss, test_accuracy = model.evaluate(test_data, verbose=1)

    # Predictions
    predictions = model.predict(test_data)
    predicted_classes = np.argmax(predictions, axis=1)
    true_labels = test_data.classes

    # Metrics
    cm = confusion_matrix(true_labels, predicted_classes)
    report = classification_report(true_labels, predicted_classes, target_names=train_data.class_indices.keys(), output_dict=True)

    # Store results
    all_results.append({
        "Fold": i,
        "Test Accuracy": test_accuracy,
        "Test Loss": test_loss,
        "Precision": report["weighted avg"]["precision"],
        "Recall": report["weighted avg"]["recall"],
        "F1-Score": report["weighted avg"]["f1-score"]
    })

# Save results
results_df = pd.DataFrame(all_results)
results_excel_file = os.path.join(results_path, "denseNet_OCTDL_5CV_results_finetuned.xlsx")
results_df.to_excel(results_excel_file, index=False)
print(f"✅ All results saved to {results_excel_file}")
# Out:
# ========== Training on Fold 1 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# 2025-04-02 23:51:24.858443: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-04-02 23:51:24.858482: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-04-02 23:51:24.858487: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-04-02 23:51:24.859162: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-02 23:51:24.859184: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 2025-04-02 23:51:29.920989: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1009 - loss: 2.8390
# Epoch 1: val_accuracy improved from -inf to 0.06154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.1076 - loss: 2.9002 - val_accuracy: 0.0615 - val_loss: 2.6524 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.2026 - loss: 3.4192
# Epoch 2: val_accuracy improved from 0.06154 to 0.07692, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.2063 - loss: 3.3537 - val_accuracy: 0.0769 - val_loss: 2.8218 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.2942 - loss: 2.0732
# Epoch 3: val_accuracy improved from 0.07692 to 0.09231, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.2848 - loss: 2.1501 - val_accuracy: 0.0923 - val_loss: 2.9244 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2017 - loss: 2.3103
# Epoch 4: val_accuracy did not improve from 0.09231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.2029 - loss: 2.3183 - val_accuracy: 0.0308 - val_loss: 2.9608 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2208 - loss: 2.4683
# Epoch 5: val_accuracy did not improve from 0.09231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.2201 - loss: 2.4769 - val_accuracy: 0.0462 - val_loss: 2.7996 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 787ms/step - accuracy: 0.2329 - loss: 2.3557
# Epoch 6: val_accuracy improved from 0.09231 to 0.10769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.2366 - loss: 2.3601 - val_accuracy: 0.1077 - val_loss: 2.5032 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3013 - loss: 1.9372
# Epoch 7: val_accuracy improved from 0.10769 to 0.15385, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.3023 - loss: 1.9600 - val_accuracy: 0.1538 - val_loss: 2.2908 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3402 - loss: 2.3859
# Epoch 8: val_accuracy did not improve from 0.15385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.3366 - loss: 2.3442 - val_accuracy: 0.1538 - val_loss: 2.2401 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - accuracy: 0.2797 - loss: 2.4669
# Epoch 9: val_accuracy improved from 0.15385 to 0.18462, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2918 - loss: 2.3817 - val_accuracy: 0.1846 - val_loss: 2.1577 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.3720 - loss: 1.9132
# Epoch 10: val_accuracy improved from 0.18462 to 0.26154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3709 - loss: 1.9234 - val_accuracy: 0.2615 - val_loss: 2.0182 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.3553 - loss: 1.6462
# Epoch 11: val_accuracy improved from 0.26154 to 0.32308, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3531 - loss: 1.6798 - val_accuracy: 0.3231 - val_loss: 1.9170 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 631ms/step - accuracy: 0.3179 - loss: 2.6540
# Epoch 12: val_accuracy did not improve from 0.32308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 836ms/step - accuracy: 0.3219 - loss: 2.5768 - val_accuracy: 0.3231 - val_loss: 1.9205 - learning_rate: 1.0000e-04
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.2068 - loss: 1.9007
# Epoch 13: val_accuracy improved from 0.32308 to 0.40000, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2222 - loss: 1.9061 - val_accuracy: 0.4000 - val_loss: 1.8512 - learning_rate: 1.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.3739 - loss: 1.6524
# Epoch 14: val_accuracy did not improve from 0.40000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 871ms/step - accuracy: 0.3743 - loss: 1.6917 - val_accuracy: 0.3538 - val_loss: 1.8044 - learning_rate: 1.0000e-04
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.3927 - loss: 1.8809
# Epoch 15: val_accuracy did not improve from 0.40000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 913ms/step - accuracy: 0.3869 - loss: 1.8800 - val_accuracy: 0.3385 - val_loss: 1.7978 - learning_rate: 1.0000e-04
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.4547 - loss: 1.4821
# Epoch 16: val_accuracy did not improve from 0.40000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.4515 - loss: 1.5079 - val_accuracy: 0.4000 - val_loss: 1.6677 - learning_rate: 1.0000e-04
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 689ms/step - accuracy: 0.4296 - loss: 1.5052
# Epoch 17: val_accuracy improved from 0.40000 to 0.43077, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.4352 - loss: 1.5022 - val_accuracy: 0.4308 - val_loss: 1.5950 - learning_rate: 1.0000e-04
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.4390 - loss: 1.9985
# Epoch 18: val_accuracy improved from 0.43077 to 0.44615, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.4398 - loss: 2.0004 - val_accuracy: 0.4462 - val_loss: 1.6430 - learning_rate: 1.0000e-04
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.3949 - loss: 1.5083
# Epoch 19: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 852ms/step - accuracy: 0.3931 - loss: 1.5128 - val_accuracy: 0.3538 - val_loss: 1.8862 - learning_rate: 1.0000e-04
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.3728 - loss: 1.3834
# Epoch 20: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 944ms/step - accuracy: 0.3777 - loss: 1.4000 - val_accuracy: 0.4000 - val_loss: 1.7684 - learning_rate: 1.0000e-04
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.3812 - loss: 1.7638
# Epoch 21: val_accuracy improved from 0.44615 to 0.47692, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3831 - loss: 1.7488 - val_accuracy: 0.4769 - val_loss: 1.6027 - learning_rate: 1.0000e-04
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.4059 - loss: 1.4641
# Epoch 22: val_accuracy improved from 0.47692 to 0.50769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.4087 - loss: 1.4769 - val_accuracy: 0.5077 - val_loss: 1.4723 - learning_rate: 1.0000e-04
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 675ms/step - accuracy: 0.5515 - loss: 1.7957
# Epoch 23: val_accuracy improved from 0.50769 to 0.56923, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.5468 - loss: 1.7899 - val_accuracy: 0.5692 - val_loss: 1.3954 - learning_rate: 1.0000e-04
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 677ms/step - accuracy: 0.5325 - loss: 1.4191
# Epoch 24: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 878ms/step - accuracy: 0.5305 - loss: 1.4386 - val_accuracy: 0.5692 - val_loss: 1.3626 - learning_rate: 1.0000e-04
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.4045 - loss: 1.9517
# Epoch 25: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.4208 - loss: 1.8896 - val_accuracy: 0.5231 - val_loss: 1.4361 - learning_rate: 1.0000e-04
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.4464 - loss: 1.4843
# Epoch 26: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 931ms/step - accuracy: 0.4488 - loss: 1.4913 - val_accuracy: 0.4769 - val_loss: 1.4489 - learning_rate: 1.0000e-04
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 675ms/step - accuracy: 0.4487 - loss: 1.2783
# Epoch 27: val_accuracy did not improve from 0.56923
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 900ms/step - accuracy: 0.4561 - loss: 1.3134 - val_accuracy: 0.5385 - val_loss: 1.3920 - learning_rate: 1.0000e-04
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - accuracy: 0.4669 - loss: 1.6779
# Epoch 28: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 901ms/step - accuracy: 0.4663 - loss: 1.6845 - val_accuracy: 0.5385 - val_loss: 1.3963 - learning_rate: 2.0000e-05
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.4780 - loss: 1.5015
# Epoch 29: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 922ms/step - accuracy: 0.4802 - loss: 1.5121 - val_accuracy: 0.5231 - val_loss: 1.4091 - learning_rate: 2.0000e-05
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - accuracy: 0.4520 - loss: 1.9023
# Epoch 30: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 872ms/step - accuracy: 0.4553 - loss: 1.8670 - val_accuracy: 0.5077 - val_loss: 1.4423 - learning_rate: 2.0000e-05
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.5897 - loss: 1.4517
# Epoch 31: val_accuracy did not improve from 0.56923
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 916ms/step - accuracy: 0.5769 - loss: 1.4466 - val_accuracy: 0.5077 - val_loss: 1.4544 - learning_rate: 2.0000e-05
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.6413 - loss: 1.2201
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step
#
# ========== Training on Fold 2 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0589 - loss: 3.6377
# Epoch 1: val_accuracy improved from -inf to 0.01538, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 63s 5s/step - accuracy: 0.0664 - loss: 3.5412 - val_accuracy: 0.0154 - val_loss: 3.0685 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1904 - loss: 2.5448
# Epoch 2: val_accuracy improved from 0.01538 to 0.06154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.1932 - loss: 2.5600 - val_accuracy: 0.0615 - val_loss: 2.3462 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.2465 - loss: 3.1273
# Epoch 3: val_accuracy improved from 0.06154 to 0.12308, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2492 - loss: 3.0687 - val_accuracy: 0.1231 - val_loss: 2.2749 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.1980 - loss: 2.6361
# Epoch 4: val_accuracy improved from 0.12308 to 0.13846, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1962 - loss: 2.5852 - val_accuracy: 0.1385 - val_loss: 2.4462 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.2106 - loss: 2.5159
# Epoch 5: val_accuracy improved from 0.13846 to 0.15385, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2060 - loss: 2.5294 - val_accuracy: 0.1538 - val_loss: 2.5423 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.1893 - loss: 2.7953
# Epoch 6: val_accuracy did not improve from 0.15385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 947ms/step - accuracy: 0.1905 - loss: 2.7339 - val_accuracy: 0.1385 - val_loss: 2.6713 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.1624 - loss: 1.8320
# Epoch 7: val_accuracy improved from 0.15385 to 0.16923, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1621 - loss: 1.8719 - val_accuracy: 0.1692 - val_loss: 2.5111 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.1500 - loss: 1.7902
# Epoch 8: val_accuracy improved from 0.16923 to 0.20000, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.1542 - loss: 1.8589 - val_accuracy: 0.2000 - val_loss: 2.3287 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 828ms/step - accuracy: 0.2114 - loss: 2.6616
# Epoch 9: val_accuracy improved from 0.20000 to 0.21538, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.2103 - loss: 2.6442 - val_accuracy: 0.2154 - val_loss: 2.2585 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2639 - loss: 2.0693
# Epoch 10: val_accuracy did not improve from 0.21538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.2668 - loss: 2.0705 - val_accuracy: 0.2000 - val_loss: 2.1820 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1809 - loss: 2.1875
# Epoch 11: val_accuracy improved from 0.21538 to 0.23077, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1815 - loss: 2.1613 - val_accuracy: 0.2308 - val_loss: 1.9887 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2606 - loss: 1.6979
# Epoch 12: val_accuracy improved from 0.23077 to 0.26154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.2587 - loss: 1.7496 - val_accuracy: 0.2615 - val_loss: 1.8480 - learning_rate: 1.0000e-04
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.3143 - loss: 1.8710
# Epoch 13: val_accuracy improved from 0.26154 to 0.32308, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3206 - loss: 1.8643 - val_accuracy: 0.3231 - val_loss: 1.7555 - learning_rate: 1.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.2962 - loss: 1.9377
# Epoch 14: val_accuracy did not improve from 0.32308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2971 - loss: 1.9632 - val_accuracy: 0.2923 - val_loss: 1.7922 - learning_rate: 1.0000e-04
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - accuracy: 0.2516 - loss: 2.0533
# Epoch 15: val_accuracy did not improve from 0.32308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2527 - loss: 2.0334 - val_accuracy: 0.2769 - val_loss: 1.8044 - learning_rate: 1.0000e-04
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - accuracy: 0.3317 - loss: 1.8373
# Epoch 16: val_accuracy did not improve from 0.32308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3310 - loss: 1.8416 - val_accuracy: 0.2615 - val_loss: 1.8402 - learning_rate: 1.0000e-04
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.2900 - loss: 2.3941
# Epoch 17: val_accuracy did not improve from 0.32308
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.2909 - loss: 2.3733 - val_accuracy: 0.2923 - val_loss: 1.7818 - learning_rate: 1.0000e-04
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.2899 - loss: 2.3424
# Epoch 18: val_accuracy did not improve from 0.32308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 937ms/step - accuracy: 0.2908 - loss: 2.2812 - val_accuracy: 0.2923 - val_loss: 1.7615 - learning_rate: 2.0000e-05
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.3958 - loss: 1.9160
# Epoch 19: val_accuracy did not improve from 0.32308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 955ms/step - accuracy: 0.3851 - loss: 1.9190 - val_accuracy: 0.3077 - val_loss: 1.7347 - learning_rate: 2.0000e-05
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 724ms/step - accuracy: 0.3330 - loss: 1.7520
# Epoch 20: val_accuracy did not improve from 0.32308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 932ms/step - accuracy: 0.3322 - loss: 1.7496 - val_accuracy: 0.3077 - val_loss: 1.7309 - learning_rate: 2.0000e-05
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.3075 - loss: 1.7200
# Epoch 21: val_accuracy improved from 0.32308 to 0.35385, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3139 - loss: 1.7291 - val_accuracy: 0.3538 - val_loss: 1.7137 - learning_rate: 2.0000e-05
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.3149 - loss: 1.9606
# Epoch 22: val_accuracy did not improve from 0.35385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 939ms/step - accuracy: 0.3166 - loss: 1.9244 - val_accuracy: 0.3385 - val_loss: 1.6994 - learning_rate: 2.0000e-05
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.3579 - loss: 2.0187
# Epoch 23: val_accuracy did not improve from 0.35385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 898ms/step - accuracy: 0.3588 - loss: 2.0056 - val_accuracy: 0.3385 - val_loss: 1.6986 - learning_rate: 2.0000e-05
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.3951 - loss: 1.9853
# Epoch 24: val_accuracy did not improve from 0.35385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 950ms/step - accuracy: 0.3933 - loss: 1.9737 - val_accuracy: 0.3385 - val_loss: 1.6926 - learning_rate: 2.0000e-05
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - accuracy: 0.3639 - loss: 2.0389
# Epoch 25: val_accuracy did not improve from 0.35385
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 957ms/step - accuracy: 0.3604 - loss: 2.0225 - val_accuracy: 0.3385 - val_loss: 1.6823 - learning_rate: 2.0000e-05
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - accuracy: 0.2531 - loss: 1.9116
# Epoch 26: val_accuracy did not improve from 0.35385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 980ms/step - accuracy: 0.2601 - loss: 1.9036 - val_accuracy: 0.3385 - val_loss: 1.6831 - learning_rate: 4.0000e-06
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.4334 - loss: 1.6655
# Epoch 27: val_accuracy did not improve from 0.35385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 956ms/step - accuracy: 0.4279 - loss: 1.6583 - val_accuracy: 0.3538 - val_loss: 1.6924 - learning_rate: 4.0000e-06
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - accuracy: 0.3212 - loss: 1.8645
# Epoch 28: val_accuracy did not improve from 0.35385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 858ms/step - accuracy: 0.3220 - loss: 1.8677 - val_accuracy: 0.3538 - val_loss: 1.6980 - learning_rate: 4.0000e-06
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - accuracy: 0.2900 - loss: 1.5633
# Epoch 29: val_accuracy improved from 0.35385 to 0.38462, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2997 - loss: 1.6086 - val_accuracy: 0.3846 - val_loss: 1.7005 - learning_rate: 4.0000e-06
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.3821 - loss: 1.7448
# Epoch 30: val_accuracy did not improve from 0.38462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 923ms/step - accuracy: 0.3840 - loss: 1.7129 - val_accuracy: 0.3846 - val_loss: 1.7091 - learning_rate: 4.0000e-06
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.4220 - loss: 1.8062
# Epoch 31: val_accuracy did not improve from 0.38462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 948ms/step - accuracy: 0.4234 - loss: 1.8150 - val_accuracy: 0.3846 - val_loss: 1.7086 - learning_rate: 4.0000e-06
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 0.2736 - loss: 1.7315
# Epoch 32: val_accuracy did not improve from 0.38462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2804 - loss: 1.7536 - val_accuracy: 0.3846 - val_loss: 1.7054 - learning_rate: 4.0000e-06
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 785ms/step - accuracy: 0.3734 - loss: 3.3514
# Epoch 33: val_accuracy did not improve from 0.38462
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 996ms/step - accuracy: 0.3703 - loss: 3.1769 - val_accuracy: 0.3692 - val_loss: 1.7187 - learning_rate: 4.0000e-06
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.2969 - loss: 2.1171
# Epoch 34: val_accuracy did not improve from 0.38462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 909ms/step - accuracy: 0.2995 - loss: 2.0870 - val_accuracy: 0.3538 - val_loss: 1.7245 - learning_rate: 8.0000e-07
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.2975 - loss: 1.9541
# Epoch 35: val_accuracy did not improve from 0.38462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 912ms/step - accuracy: 0.2965 - loss: 1.9421 - val_accuracy: 0.3538 - val_loss: 1.7238 - learning_rate: 8.0000e-07
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.3067 - loss: 1.6200
# Epoch 36: val_accuracy did not improve from 0.38462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 996ms/step - accuracy: 0.3131 - loss: 1.6154 - val_accuracy: 0.3538 - val_loss: 1.7273 - learning_rate: 8.0000e-07
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 793ms/step - accuracy: 0.3660 - loss: 2.0647
# Epoch 37: val_accuracy did not improve from 0.38462
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 996ms/step - accuracy: 0.3640 - loss: 2.0330 - val_accuracy: 0.3538 - val_loss: 1.7297 - learning_rate: 8.0000e-07
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 29.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.2860 - loss: 1.8317
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step
#
# ========== Training on Fold 3 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1722 - loss: 2.4112
# Epoch 1: val_accuracy improved from -inf to 0.04615, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 60s 6s/step - accuracy: 0.1794 - loss: 2.4833 - val_accuracy: 0.0462 - val_loss: 2.6178 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1995 - loss: 2.3226
# Epoch 2: val_accuracy did not improve from 0.04615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.1983 - loss: 2.3432 - val_accuracy: 0.0462 - val_loss: 2.6101 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 857ms/step - accuracy: 0.2558 - loss: 2.7387
# Epoch 3: val_accuracy improved from 0.04615 to 0.06154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.2545 - loss: 2.7279 - val_accuracy: 0.0615 - val_loss: 2.5617 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.1673 - loss: 2.4135
# Epoch 4: val_accuracy improved from 0.06154 to 0.10769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.1743 - loss: 2.3908 - val_accuracy: 0.1077 - val_loss: 2.5089 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 757ms/step - accuracy: 0.2303 - loss: 2.4686
# Epoch 5: val_accuracy improved from 0.10769 to 0.15385, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2335 - loss: 2.4494 - val_accuracy: 0.1538 - val_loss: 2.3138 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - accuracy: 0.2060 - loss: 2.6331
# Epoch 6: val_accuracy improved from 0.15385 to 0.21538, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2048 - loss: 2.5858 - val_accuracy: 0.2154 - val_loss: 2.1528 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - accuracy: 0.2509 - loss: 1.9750
# Epoch 7: val_accuracy improved from 0.21538 to 0.26154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2609 - loss: 1.9794 - val_accuracy: 0.2615 - val_loss: 1.9320 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 775ms/step - accuracy: 0.3295 - loss: 1.8627
# Epoch 8: val_accuracy improved from 0.26154 to 0.30769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3318 - loss: 1.8764 - val_accuracy: 0.3077 - val_loss: 1.8115 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.3847 - loss: 2.1633
# Epoch 9: val_accuracy improved from 0.30769 to 0.33846, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3844 - loss: 2.1434 - val_accuracy: 0.3385 - val_loss: 1.8102 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.2052 - loss: 2.0590
# Epoch 10: val_accuracy improved from 0.33846 to 0.38462, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.2165 - loss: 2.0601 - val_accuracy: 0.3846 - val_loss: 1.6701 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.3261 - loss: 1.6571
# Epoch 11: val_accuracy did not improve from 0.38462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3298 - loss: 1.6639 - val_accuracy: 0.3692 - val_loss: 1.6713 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 894ms/step - accuracy: 0.3872 - loss: 1.8127
# Epoch 12: val_accuracy did not improve from 0.38462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3848 - loss: 1.8257 - val_accuracy: 0.3538 - val_loss: 1.6663 - learning_rate: 1.0000e-04
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3912 - loss: 1.6743
# Epoch 13: val_accuracy improved from 0.38462 to 0.43077, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.3909 - loss: 1.6766 - val_accuracy: 0.4308 - val_loss: 1.5866 - learning_rate: 1.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3284 - loss: 1.6988
# Epoch 14: val_accuracy improved from 0.43077 to 0.52308, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.3344 - loss: 1.7261 - val_accuracy: 0.5231 - val_loss: 1.4362 - learning_rate: 1.0000e-04
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4774 - loss: 1.2719
# Epoch 15: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.4727 - loss: 1.2916 - val_accuracy: 0.5077 - val_loss: 1.4278 - learning_rate: 1.0000e-04
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2743 - loss: 1.7293
# Epoch 16: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.2748 - loss: 1.7499 - val_accuracy: 0.5077 - val_loss: 1.4771 - learning_rate: 1.0000e-04
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3093 - loss: 1.8461
# Epoch 17: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.3119 - loss: 1.8263 - val_accuracy: 0.4615 - val_loss: 1.5185 - learning_rate: 1.0000e-04
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3918 - loss: 1.9021
# Epoch 18: val_accuracy did not improve from 0.52308
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3932 - loss: 1.8829 - val_accuracy: 0.4462 - val_loss: 1.5168 - learning_rate: 1.0000e-04
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - accuracy: 0.4334 - loss: 1.5283
# Epoch 19: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.4306 - loss: 1.5354 - val_accuracy: 0.4615 - val_loss: 1.4859 - learning_rate: 2.0000e-05
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 979ms/step - accuracy: 0.4592 - loss: 1.3947
# Epoch 20: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.4580 - loss: 1.4135 - val_accuracy: 0.4769 - val_loss: 1.4448 - learning_rate: 2.0000e-05
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.5041 - loss: 1.2972
# Epoch 21: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 44s 9s/step - accuracy: 0.4991 - loss: 1.3293 - val_accuracy: 0.5231 - val_loss: 1.4224 - learning_rate: 2.0000e-05
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4293 - loss: 1.3091
# Epoch 22: val_accuracy improved from 0.52308 to 0.56923, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 5s/step - accuracy: 0.4332 - loss: 1.3256 - val_accuracy: 0.5692 - val_loss: 1.3993 - learning_rate: 2.0000e-05
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4308 - loss: 1.4181
# Epoch 23: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.4337 - loss: 1.4362 - val_accuracy: 0.5538 - val_loss: 1.3886 - learning_rate: 2.0000e-05
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 895ms/step - accuracy: 0.3789 - loss: 1.8370
# Epoch 24: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3856 - loss: 1.8016 - val_accuracy: 0.5538 - val_loss: 1.3695 - learning_rate: 2.0000e-05
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.5010 - loss: 1.5109
# Epoch 25: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 971ms/step - accuracy: 0.4982 - loss: 1.5008 - val_accuracy: 0.5692 - val_loss: 1.3606 - learning_rate: 2.0000e-05
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.3994 - loss: 1.5262
# Epoch 26: val_accuracy did not improve from 0.56923
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.4032 - loss: 1.5513 - val_accuracy: 0.5538 - val_loss: 1.3613 - learning_rate: 2.0000e-05
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - accuracy: 0.5663 - loss: 1.3868
# Epoch 27: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.5568 - loss: 1.4076 - val_accuracy: 0.5538 - val_loss: 1.3634 - learning_rate: 4.0000e-06
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4578 - loss: 1.6041
# Epoch 28: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.4568 - loss: 1.5865 - val_accuracy: 0.5692 - val_loss: 1.3642 - learning_rate: 4.0000e-06
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5522 - loss: 1.7252
# Epoch 29: val_accuracy improved from 0.56923 to 0.58462, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.5509 - loss: 1.7141 - val_accuracy: 0.5846 - val_loss: 1.3687 - learning_rate: 4.0000e-06
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5686 - loss: 1.2049
# Epoch 30: val_accuracy did not improve from 0.58462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5641 - loss: 1.2273 - val_accuracy: 0.5692 - val_loss: 1.3697 - learning_rate: 4.0000e-06
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3938 - loss: 1.4583
# Epoch 31: val_accuracy did not improve from 0.58462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4081 - loss: 1.4560 - val_accuracy: 0.5846 - val_loss: 1.3655 - learning_rate: 4.0000e-06
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4841 - loss: 1.5816
# Epoch 32: val_accuracy did not improve from 0.58462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.4811 - loss: 1.5655 - val_accuracy: 0.5846 - val_loss: 1.3674 - learning_rate: 4.0000e-06
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4209 - loss: 1.2481
# Epoch 33: val_accuracy did not improve from 0.58462
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.4287 - loss: 1.2518 - val_accuracy: 0.5846 - val_loss: 1.3600 - learning_rate: 4.0000e-06
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4806 - loss: 1.3288
# Epoch 34: val_accuracy did not improve from 0.58462
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.4834 - loss: 1.3316 - val_accuracy: 0.5846 - val_loss: 1.3581 - learning_rate: 8.0000e-07
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5184 - loss: 1.3516
# Epoch 35: val_accuracy improved from 0.58462 to 0.60000, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5149 - loss: 1.3670 - val_accuracy: 0.6000 - val_loss: 1.3684 - learning_rate: 8.0000e-07
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5257 - loss: 1.3351
# Epoch 36: val_accuracy did not improve from 0.60000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.5229 - loss: 1.3539 - val_accuracy: 0.6000 - val_loss: 1.3640 - learning_rate: 8.0000e-07
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4620 - loss: 1.2230
# Epoch 37: val_accuracy did not improve from 0.60000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4718 - loss: 1.2346 - val_accuracy: 0.6000 - val_loss: 1.3674 - learning_rate: 8.0000e-07
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4574 - loss: 1.4706
# Epoch 38: val_accuracy did not improve from 0.60000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.4565 - loss: 1.4988 - val_accuracy: 0.6000 - val_loss: 1.3738 - learning_rate: 8.0000e-07
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.5392 - loss: 1.3100
# Epoch 39: val_accuracy did not improve from 0.60000
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.5371 - loss: 1.3272 - val_accuracy: 0.6000 - val_loss: 1.3761 - learning_rate: 8.0000e-07
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 856ms/step - accuracy: 0.4658 - loss: 1.6209
# Epoch 40: val_accuracy did not improve from 0.60000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.4681 - loss: 1.6205 - val_accuracy: 0.6000 - val_loss: 1.3733 - learning_rate: 1.6000e-07
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4307 - loss: 1.4380
# Epoch 41: val_accuracy did not improve from 0.60000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.4370 - loss: 1.4297 - val_accuracy: 0.5846 - val_loss: 1.3770 - learning_rate: 1.6000e-07
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4531 - loss: 1.3254
# Epoch 42: val_accuracy did not improve from 0.60000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.4545 - loss: 1.3384 - val_accuracy: 0.6000 - val_loss: 1.3758 - learning_rate: 1.6000e-07
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4665 - loss: 1.8072
# Epoch 43: val_accuracy did not improve from 0.60000
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.4660 - loss: 1.8002 - val_accuracy: 0.5846 - val_loss: 1.3810 - learning_rate: 1.6000e-07
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 35.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.4012 - loss: 1.8252
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x4024039a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x4024039a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 28s 4s/step
#
# ========== Training on Fold 4 ==========
# Found 161 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1612 - loss: 2.9944
# Epoch 1: val_accuracy improved from -inf to 0.20000, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.1648 - loss: 2.9763 - val_accuracy: 0.2000 - val_loss: 1.9221 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40s/step - accuracy: 0.3059 - loss: 2.5173
# Epoch 2: val_accuracy improved from 0.20000 to 0.23077, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 223s 44s/step - accuracy: 0.3031 - loss: 2.4893 - val_accuracy: 0.2308 - val_loss: 1.7994 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3038 - loss: 2.2451
# Epoch 3: val_accuracy improved from 0.23077 to 0.24615, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.3048 - loss: 2.2544 - val_accuracy: 0.2462 - val_loss: 1.7782 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2379 - loss: 2.6014
# Epoch 4: val_accuracy did not improve from 0.24615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.2403 - loss: 2.5636 - val_accuracy: 0.1692 - val_loss: 1.9497 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - accuracy: 0.1905 - loss: 2.6389
# Epoch 5: val_accuracy did not improve from 0.24615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1943 - loss: 2.5848 - val_accuracy: 0.1385 - val_loss: 2.1099 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2226 - loss: 2.5908
# Epoch 6: val_accuracy did not improve from 0.24615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.2219 - loss: 2.5473 - val_accuracy: 0.1846 - val_loss: 1.9211 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - accuracy: 0.2728 - loss: 2.3035
# Epoch 7: val_accuracy improved from 0.24615 to 0.38462, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.2782 - loss: 2.2475 - val_accuracy: 0.3846 - val_loss: 1.6509 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 787ms/step - accuracy: 0.1847 - loss: 2.2032
# Epoch 8: val_accuracy improved from 0.38462 to 0.47692, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.1929 - loss: 2.2056 - val_accuracy: 0.4769 - val_loss: 1.5382 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.2998 - loss: 2.2559
# Epoch 9: val_accuracy improved from 0.47692 to 0.52308, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.3022 - loss: 2.2090 - val_accuracy: 0.5231 - val_loss: 1.4981 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.2413 - loss: 2.0155
# Epoch 10: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.2485 - loss: 2.0157 - val_accuracy: 0.4923 - val_loss: 1.4818 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - accuracy: 0.3094 - loss: 1.9282
# Epoch 11: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.3149 - loss: 1.9253 - val_accuracy: 0.4923 - val_loss: 1.4616 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.3789 - loss: 1.6961
# Epoch 12: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.3780 - loss: 1.7347 - val_accuracy: 0.4000 - val_loss: 1.5314 - learning_rate: 1.0000e-04
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 828ms/step - accuracy: 0.3625 - loss: 1.4714
# Epoch 13: val_accuracy did not improve from 0.52308
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3577 - loss: 1.5108 - val_accuracy: 0.4615 - val_loss: 1.5253 - learning_rate: 1.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.2622 - loss: 1.5984
# Epoch 14: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2727 - loss: 1.6209 - val_accuracy: 0.4769 - val_loss: 1.5153 - learning_rate: 2.0000e-05
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.3217 - loss: 1.8598
# Epoch 15: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 989ms/step - accuracy: 0.3219 - loss: 1.8418 - val_accuracy: 0.5077 - val_loss: 1.5027 - learning_rate: 2.0000e-05
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 762ms/step - accuracy: 0.2883 - loss: 2.2544
# Epoch 16: val_accuracy did not improve from 0.52308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 990ms/step - accuracy: 0.2933 - loss: 2.2072 - val_accuracy: 0.4923 - val_loss: 1.4844 - learning_rate: 2.0000e-05
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.3255 - loss: 4.2134
# Epoch 17: val_accuracy did not improve from 0.52308
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.3296 - loss: 3.8603 - val_accuracy: 0.4923 - val_loss: 1.4770 - learning_rate: 2.0000e-05
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 421ms/step - accuracy: 0.3578 - loss: 1.6275
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step
#
# ========== Training on Fold 5 ==========
# Found 161 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1527 - loss: 2.7580
# Epoch 1: val_accuracy improved from -inf to 0.04615, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 121s 13s/step - accuracy: 0.1548 - loss: 2.7241 - val_accuracy: 0.0462 - val_loss: 3.6471 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1835 - loss: 2.4564
# Epoch 2: val_accuracy did not improve from 0.04615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.1910 - loss: 2.4773 - val_accuracy: 0.0462 - val_loss: 3.1821 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.2746 - loss: 2.4417
# Epoch 3: val_accuracy did not improve from 0.04615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.2736 - loss: 2.4344 - val_accuracy: 0.0462 - val_loss: 2.7463 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - accuracy: 0.2673 - loss: 2.2088
# Epoch 4: val_accuracy improved from 0.04615 to 0.09231, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.2672 - loss: 2.2292 - val_accuracy: 0.0923 - val_loss: 2.5142 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - accuracy: 0.3668 - loss: 1.8606
# Epoch 5: val_accuracy improved from 0.09231 to 0.10769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3596 - loss: 1.9071 - val_accuracy: 0.1077 - val_loss: 2.4645 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.2456 - loss: 2.1935
# Epoch 6: val_accuracy did not improve from 0.10769
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2487 - loss: 2.1833 - val_accuracy: 0.1077 - val_loss: 2.5719 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.2575 - loss: 2.0843
# Epoch 7: val_accuracy did not improve from 0.10769
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 998ms/step - accuracy: 0.2526 - loss: 2.0815 - val_accuracy: 0.0923 - val_loss: 2.8067 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 809ms/step - accuracy: 0.3457 - loss: 1.8463
# Epoch 8: val_accuracy improved from 0.10769 to 0.13846, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.3336 - loss: 1.8887 - val_accuracy: 0.1385 - val_loss: 2.4922 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - accuracy: 0.2887 - loss: 2.4370
# Epoch 9: val_accuracy improved from 0.13846 to 0.24615, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2883 - loss: 2.4161 - val_accuracy: 0.2462 - val_loss: 2.0609 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 793ms/step - accuracy: 0.3387 - loss: 2.0941
# Epoch 10: val_accuracy improved from 0.24615 to 0.27692, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3480 - loss: 2.0529 - val_accuracy: 0.2769 - val_loss: 1.8799 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.3797 - loss: 1.9001
# Epoch 11: val_accuracy improved from 0.27692 to 0.36923, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3875 - loss: 1.8858 - val_accuracy: 0.3692 - val_loss: 1.7461 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4171 - loss: 1.9764
# Epoch 12: val_accuracy improved from 0.36923 to 0.46154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 5s/step - accuracy: 0.4232 - loss: 1.9667 - val_accuracy: 0.4615 - val_loss: 1.6383 - learning_rate: 1.0000e-04
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4126 - loss: 1.7246
# Epoch 13: val_accuracy improved from 0.46154 to 0.50769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.4087 - loss: 1.7275 - val_accuracy: 0.5077 - val_loss: 1.4672 - learning_rate: 1.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4928 - loss: 1.5750
# Epoch 14: val_accuracy improved from 0.50769 to 0.56923, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/models/denseNet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.4969 - loss: 1.5669 - val_accuracy: 0.5692 - val_loss: 1.4386 - learning_rate: 1.0000e-04
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4298 - loss: 1.7853
# Epoch 15: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 46s 9s/step - accuracy: 0.4314 - loss: 1.7683 - val_accuracy: 0.4154 - val_loss: 1.6194 - learning_rate: 1.0000e-04
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3028 - loss: 2.2070
# Epoch 16: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.3119 - loss: 2.1546 - val_accuracy: 0.2462 - val_loss: 1.9102 - learning_rate: 1.0000e-04
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.4053 - loss: 1.5008
# Epoch 17: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.4041 - loss: 1.5015 - val_accuracy: 0.2615 - val_loss: 1.9018 - learning_rate: 1.0000e-04
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.4385 - loss: 1.4732
# Epoch 18: val_accuracy did not improve from 0.56923
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.4362 - loss: 1.4869 - val_accuracy: 0.4462 - val_loss: 1.6292 - learning_rate: 1.0000e-04
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.4596 - loss: 1.4819
# Epoch 19: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.4569 - loss: 1.4715 - val_accuracy: 0.4615 - val_loss: 1.5595 - learning_rate: 2.0000e-05
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.4938 - loss: 1.3128
# Epoch 20: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.4951 - loss: 1.3415 - val_accuracy: 0.4923 - val_loss: 1.5053 - learning_rate: 2.0000e-05
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 793ms/step - accuracy: 0.4274 - loss: 1.6719
# Epoch 21: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.4311 - loss: 1.6665 - val_accuracy: 0.5077 - val_loss: 1.4809 - learning_rate: 2.0000e-05
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - accuracy: 0.5245 - loss: 1.7045
# Epoch 22: val_accuracy did not improve from 0.56923
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.5259 - loss: 1.6859 - val_accuracy: 0.5385 - val_loss: 1.4331 - learning_rate: 2.0000e-05
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4171 - loss: 1.5238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 43s 6s/step
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ✅ All results saved to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/denseNet/octdl/results/denseNet_OCTDL_5CV_results_finetuned.xlsx

# %%
#MobileNet - OCTDL - 5CV
import os
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Enable mixed precision (works well on M1/M2 chips)
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Paths
dataset_base_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/dataset split/OCTDL_Splits"
logs_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/training"
models_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models"
results_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/results"

# Ensure all log directories exist
os.makedirs(logs_path, exist_ok=True)
os.makedirs(models_path, exist_ok=True)
os.makedirs(results_path, exist_ok=True)

# Hyperparameters
image_size = 224
batch_size = 32
epochs = 50
num_classes = 7

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    zoom_range=0.3,
    shear_range=0.2
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Results storage
all_results = []

for i in range(1, 6):
    print(f"\n========== Training on Fold {i} ==========")

    set_path = os.path.join(dataset_base_path, f"OCTDL_Set_{i}")
    train_dir, val_dir, test_dir = [os.path.join(set_path, x) for x in ["Train", "Validation", "Test"]]

    # Load data
    train_data = train_datagen.flow_from_directory(train_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical')
    val_data = val_test_datagen.flow_from_directory(val_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical')
    test_data = val_test_datagen.flow_from_directory(test_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical', shuffle=False)

    # Compute class weights
    labels = train_data.classes
    unique_classes = np.unique(labels)
    class_weights = compute_class_weight('balanced', classes=unique_classes, y=labels)
    class_weight_dict = {i: weight for i, weight in zip(unique_classes, class_weights)}

    # Load MobileNetV2
    base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(image_size, image_size, 3))
    
    # Fine-tune top 15 layers
    for layer in base_model.layers[:-15]:
        layer.trainable = False
    for layer in base_model.layers[-15:]:
        layer.trainable = True

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        Dropout(0.5),
        Dense(num_classes, activation="softmax", dtype='float32')
    ])

    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=CategoricalCrossentropy(label_smoothing=0.1),
        metrics=["accuracy"]
    )

    # Callbacks
    model_save_path = os.path.join(models_path, f"mobilenet_OCTDL_best_fold_{i}.keras")
    callbacks = [
        ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, verbose=1),
        EarlyStopping(monitor='val_accuracy', patience=8, verbose=1, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_accuracy', factor=0.2, patience=4, verbose=1),
        CSVLogger(os.path.join(logs_path, f"mobilenet_OCTDL_fold_{i}.csv"), append=True)
    ]

    # Train
    model.fit(train_data, validation_data=val_data, epochs=epochs, class_weight=class_weight_dict, callbacks=callbacks)

    # Evaluate
    test_loss, test_accuracy = model.evaluate(test_data, verbose=1)

    # Predictions
    predictions = model.predict(test_data)
    predicted_classes = np.argmax(predictions, axis=1)
    true_labels = test_data.classes

    # Metrics
    report = classification_report(true_labels, predicted_classes, target_names=train_data.class_indices.keys(), output_dict=True)

    all_results.append({
        "Fold": i,
        "Test Accuracy": test_accuracy,
        "Test Loss": test_loss,
        "Precision": report["weighted avg"]["precision"],
        "Recall": report["weighted avg"]["recall"],
        "F1-Score": report["weighted avg"]["f1-score"]
    })

# Save results
results_df = pd.DataFrame(all_results)
results_excel_file = os.path.join(results_path, "mobilenet_OCTDL_5CV_results.xlsx")
results_df.to_excel(results_excel_file, index=False)
print(f"✅ All results saved to {results_excel_file}")
# Out:
# ========== Training on Fold 1 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.1655 - loss: 2.4342
# Epoch 1: val_accuracy improved from -inf to 0.06154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.1692 - loss: 2.4384 - val_accuracy: 0.0615 - val_loss: 3.1774 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.2600 - loss: 2.4681
# Epoch 2: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - accuracy: 0.2572 - loss: 2.4315 - val_accuracy: 0.0308 - val_loss: 3.2534 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.2333 - loss: 2.0997
# Epoch 3: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 352ms/step - accuracy: 0.2344 - loss: 2.0929 - val_accuracy: 0.0308 - val_loss: 2.8860 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.3433 - loss: 2.1046
# Epoch 4: val_accuracy improved from 0.06154 to 0.16923, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 469ms/step - accuracy: 0.3418 - loss: 2.0838 - val_accuracy: 0.1692 - val_loss: 2.4237 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.4226 - loss: 2.3131
# Epoch 5: val_accuracy improved from 0.16923 to 0.26154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 468ms/step - accuracy: 0.4231 - loss: 2.2079 - val_accuracy: 0.2615 - val_loss: 2.3664 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.4743 - loss: 1.4610
# Epoch 6: val_accuracy improved from 0.26154 to 0.27692, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 408ms/step - accuracy: 0.4683 - loss: 1.4872 - val_accuracy: 0.2769 - val_loss: 2.4018 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.4038 - loss: 1.6417
# Epoch 7: val_accuracy improved from 0.27692 to 0.29231, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 404ms/step - accuracy: 0.4096 - loss: 1.6366 - val_accuracy: 0.2923 - val_loss: 2.3870 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.4648 - loss: 1.8268
# Epoch 8: val_accuracy did not improve from 0.29231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 346ms/step - accuracy: 0.4663 - loss: 1.8011 - val_accuracy: 0.2769 - val_loss: 2.5929 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.3712 - loss: 1.9260
# Epoch 9: val_accuracy did not improve from 0.29231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - accuracy: 0.3764 - loss: 1.8922 - val_accuracy: 0.2769 - val_loss: 2.5990 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.5251 - loss: 1.2832
# Epoch 10: val_accuracy did not improve from 0.29231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 338ms/step - accuracy: 0.5189 - loss: 1.3142 - val_accuracy: 0.2769 - val_loss: 2.5647 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.4554 - loss: 1.4685
# Epoch 11: val_accuracy did not improve from 0.29231
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.4468 - loss: 1.4855 - val_accuracy: 0.2769 - val_loss: 2.4275 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.4279 - loss: 1.4204
# Epoch 12: val_accuracy did not improve from 0.29231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.4250 - loss: 1.4278 - val_accuracy: 0.2769 - val_loss: 2.3986 - learning_rate: 2.0000e-05
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.4196 - loss: 1.7839
# Epoch 13: val_accuracy did not improve from 0.29231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - accuracy: 0.4222 - loss: 1.7670 - val_accuracy: 0.2769 - val_loss: 2.4256 - learning_rate: 2.0000e-05
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4332 - loss: 1.5490
# Epoch 14: val_accuracy did not improve from 0.29231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 337ms/step - accuracy: 0.4348 - loss: 1.5331 - val_accuracy: 0.2769 - val_loss: 2.4166 - learning_rate: 2.0000e-05
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.5091 - loss: 1.4189
# Epoch 15: val_accuracy did not improve from 0.29231
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - accuracy: 0.5051 - loss: 1.4119 - val_accuracy: 0.2769 - val_loss: 2.4457 - learning_rate: 2.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.2145 - loss: 2.5156
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
#
# ========== Training on Fold 2 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.1846 - loss: 3.1759
# Epoch 1: val_accuracy improved from -inf to 0.43077, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.1874 - loss: 3.0955 - val_accuracy: 0.4308 - val_loss: 1.6107 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.2783 - loss: 2.7988
# Epoch 2: val_accuracy did not improve from 0.43077
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 330ms/step - accuracy: 0.2782 - loss: 2.7665 - val_accuracy: 0.4308 - val_loss: 1.6386 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.2262 - loss: 2.1179
# Epoch 3: val_accuracy did not improve from 0.43077
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - accuracy: 0.2336 - loss: 2.1424 - val_accuracy: 0.4308 - val_loss: 1.6442 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.2940 - loss: 1.7525
# Epoch 4: val_accuracy did not improve from 0.43077
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - accuracy: 0.2969 - loss: 1.8384 - val_accuracy: 0.4154 - val_loss: 1.6040 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.2285 - loss: 1.8465
# Epoch 5: val_accuracy improved from 0.43077 to 0.46154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 513ms/step - accuracy: 0.2311 - loss: 1.8763 - val_accuracy: 0.4615 - val_loss: 1.5569 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.4264 - loss: 1.5937
# Epoch 6: val_accuracy improved from 0.46154 to 0.49231, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 439ms/step - accuracy: 0.4228 - loss: 1.5903 - val_accuracy: 0.4923 - val_loss: 1.6519 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.3359 - loss: 1.6730
# Epoch 7: val_accuracy did not improve from 0.49231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - accuracy: 0.3356 - loss: 1.6681 - val_accuracy: 0.4769 - val_loss: 1.7866 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.5163 - loss: 1.5906
# Epoch 8: val_accuracy did not improve from 0.49231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 392ms/step - accuracy: 0.5122 - loss: 1.6218 - val_accuracy: 0.4769 - val_loss: 1.7478 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.3919 - loss: 1.6682
# Epoch 9: val_accuracy did not improve from 0.49231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 403ms/step - accuracy: 0.3941 - loss: 1.6823 - val_accuracy: 0.4769 - val_loss: 1.6496 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.3831 - loss: 1.4127
# Epoch 10: val_accuracy did not improve from 0.49231
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 482ms/step - accuracy: 0.3884 - loss: 1.4388 - val_accuracy: 0.4769 - val_loss: 1.6787 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3412 - loss: 1.7690
# Epoch 11: val_accuracy did not improve from 0.49231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.3542 - loss: 1.7394 - val_accuracy: 0.4769 - val_loss: 1.6796 - learning_rate: 2.0000e-05
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4584 - loss: 1.5777
# Epoch 12: val_accuracy did not improve from 0.49231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.4564 - loss: 1.5924 - val_accuracy: 0.4923 - val_loss: 1.6784 - learning_rate: 2.0000e-05
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.4959 - loss: 1.4139
# Epoch 13: val_accuracy did not improve from 0.49231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 395ms/step - accuracy: 0.4921 - loss: 1.4381 - val_accuracy: 0.4769 - val_loss: 1.6908 - learning_rate: 2.0000e-05
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.4350 - loss: 1.3594
# Epoch 14: val_accuracy did not improve from 0.49231
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 329ms/step - accuracy: 0.4337 - loss: 1.3981 - val_accuracy: 0.4769 - val_loss: 1.7069 - learning_rate: 2.0000e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.3360 - loss: 1.7971
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step
#
# ========== Training on Fold 3 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2045 - loss: 2.0612
# Epoch 1: val_accuracy improved from -inf to 0.27692, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.2008 - loss: 2.1217 - val_accuracy: 0.2769 - val_loss: 1.9646 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 943ms/step - accuracy: 0.2681 - loss: 2.1763
# Epoch 2: val_accuracy improved from 0.27692 to 0.47692, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2677 - loss: 2.1582 - val_accuracy: 0.4769 - val_loss: 1.6772 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.3663 - loss: 2.4358
# Epoch 3: val_accuracy improved from 0.47692 to 0.50769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 637ms/step - accuracy: 0.3643 - loss: 2.3859 - val_accuracy: 0.5077 - val_loss: 1.5992 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.3287 - loss: 1.9940
# Epoch 4: val_accuracy improved from 0.50769 to 0.52308, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 581ms/step - accuracy: 0.3267 - loss: 1.9779 - val_accuracy: 0.5231 - val_loss: 1.5535 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.3190 - loss: 1.6641
# Epoch 5: val_accuracy improved from 0.52308 to 0.53846, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 499ms/step - accuracy: 0.3192 - loss: 1.6737 - val_accuracy: 0.5385 - val_loss: 1.4986 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.2997 - loss: 1.8270
# Epoch 6: val_accuracy improved from 0.53846 to 0.55385, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 396ms/step - accuracy: 0.3018 - loss: 1.8064 - val_accuracy: 0.5538 - val_loss: 1.4927 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.2814 - loss: 1.3450
# Epoch 7: val_accuracy did not improve from 0.55385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 470ms/step - accuracy: 0.2941 - loss: 1.3775 - val_accuracy: 0.5385 - val_loss: 1.5399 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.3808 - loss: 1.6682
# Epoch 8: val_accuracy did not improve from 0.55385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 324ms/step - accuracy: 0.3881 - loss: 1.6624 - val_accuracy: 0.5231 - val_loss: 1.5899 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5542 - loss: 1.3494
# Epoch 9: val_accuracy did not improve from 0.55385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 331ms/step - accuracy: 0.5535 - loss: 1.3539 - val_accuracy: 0.5077 - val_loss: 1.6286 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.4636 - loss: 1.4669
# Epoch 10: val_accuracy did not improve from 0.55385
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.4661 - loss: 1.4747 - val_accuracy: 0.5231 - val_loss: 1.6123 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.5576 - loss: 1.2348
# Epoch 11: val_accuracy did not improve from 0.55385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 478ms/step - accuracy: 0.5564 - loss: 1.2544 - val_accuracy: 0.5231 - val_loss: 1.6132 - learning_rate: 2.0000e-05
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.6030 - loss: 1.5344
# Epoch 12: val_accuracy did not improve from 0.55385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - accuracy: 0.5998 - loss: 1.5217 - val_accuracy: 0.5231 - val_loss: 1.5812 - learning_rate: 2.0000e-05
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.5429 - loss: 1.9213
# Epoch 13: val_accuracy did not improve from 0.55385
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 394ms/step - accuracy: 0.5474 - loss: 1.8326 - val_accuracy: 0.5538 - val_loss: 1.5366 - learning_rate: 2.0000e-05
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4838 - loss: 1.3184
# Epoch 14: val_accuracy improved from 0.55385 to 0.60000, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 424ms/step - accuracy: 0.4923 - loss: 1.3256 - val_accuracy: 0.6000 - val_loss: 1.5163 - learning_rate: 2.0000e-05
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5838 - loss: 1.0466
# Epoch 15: val_accuracy did not improve from 0.60000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step - accuracy: 0.5842 - loss: 1.0573 - val_accuracy: 0.6000 - val_loss: 1.5082 - learning_rate: 2.0000e-05
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.5503 - loss: 1.1231
# Epoch 16: val_accuracy improved from 0.60000 to 0.61538, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 464ms/step - accuracy: 0.5493 - loss: 1.1494 - val_accuracy: 0.6154 - val_loss: 1.5103 - learning_rate: 2.0000e-05
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.7136 - loss: 1.1353
# Epoch 17: val_accuracy did not improve from 0.61538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 408ms/step - accuracy: 0.6972 - loss: 1.1417 - val_accuracy: 0.6154 - val_loss: 1.5198 - learning_rate: 2.0000e-05
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.6416 - loss: 1.1757
# Epoch 18: val_accuracy did not improve from 0.61538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 0.6434 - loss: 1.1715 - val_accuracy: 0.6154 - val_loss: 1.5237 - learning_rate: 2.0000e-05
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.6299 - loss: 1.1662
# Epoch 19: val_accuracy did not improve from 0.61538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 399ms/step - accuracy: 0.6272 - loss: 1.1711 - val_accuracy: 0.6154 - val_loss: 1.5042 - learning_rate: 2.0000e-05
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.5480 - loss: 1.2850
# Epoch 20: val_accuracy did not improve from 0.61538
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - accuracy: 0.5508 - loss: 1.2659 - val_accuracy: 0.6154 - val_loss: 1.4942 - learning_rate: 2.0000e-05
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.6037 - loss: 1.2494
# Epoch 21: val_accuracy did not improve from 0.61538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 385ms/step - accuracy: 0.6039 - loss: 1.2400 - val_accuracy: 0.6154 - val_loss: 1.4921 - learning_rate: 4.0000e-06
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.4325 - loss: 1.7018
# Epoch 22: val_accuracy did not improve from 0.61538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 387ms/step - accuracy: 0.4492 - loss: 1.6504 - val_accuracy: 0.6154 - val_loss: 1.4875 - learning_rate: 4.0000e-06
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.6650 - loss: 1.7021
# Epoch 23: val_accuracy did not improve from 0.61538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 387ms/step - accuracy: 0.6502 - loss: 1.6387 - val_accuracy: 0.6154 - val_loss: 1.4846 - learning_rate: 4.0000e-06
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.5233 - loss: 1.4461
# Epoch 24: val_accuracy did not improve from 0.61538
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - accuracy: 0.5243 - loss: 1.4416 - val_accuracy: 0.6154 - val_loss: 1.4786 - learning_rate: 4.0000e-06
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.4761 - loss: 1.5875
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step
#
# ========== Training on Fold 4 ==========
# Found 161 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0707 - loss: 2.7032
# Epoch 1: val_accuracy improved from -inf to 0.23077, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.0730 - loss: 2.6974 - val_accuracy: 0.2308 - val_loss: 1.8287 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.1338 - loss: 2.4423
# Epoch 2: val_accuracy improved from 0.23077 to 0.32308, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 497ms/step - accuracy: 0.1395 - loss: 2.4572 - val_accuracy: 0.3231 - val_loss: 1.8931 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.2683 - loss: 2.0698
# Epoch 3: val_accuracy did not improve from 0.32308
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 0.2611 - loss: 2.0839 - val_accuracy: 0.3231 - val_loss: 1.7361 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.2465 - loss: 1.9648
# Epoch 4: val_accuracy improved from 0.32308 to 0.50769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 413ms/step - accuracy: 0.2530 - loss: 1.9469 - val_accuracy: 0.5077 - val_loss: 1.4981 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.3830 - loss: 1.8324
# Epoch 5: val_accuracy improved from 0.50769 to 0.55385, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 452ms/step - accuracy: 0.3878 - loss: 1.8212 - val_accuracy: 0.5538 - val_loss: 1.4225 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.2847 - loss: 1.7327
# Epoch 6: val_accuracy improved from 0.55385 to 0.56923, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 448ms/step - accuracy: 0.2866 - loss: 1.7371 - val_accuracy: 0.5692 - val_loss: 1.4238 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.3617 - loss: 1.7457
# Epoch 7: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - accuracy: 0.3650 - loss: 1.7244 - val_accuracy: 0.5538 - val_loss: 1.4904 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.3440 - loss: 1.6735
# Epoch 8: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step - accuracy: 0.3454 - loss: 1.6529 - val_accuracy: 0.5538 - val_loss: 1.5592 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.3561 - loss: 1.5514
# Epoch 9: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 381ms/step - accuracy: 0.3709 - loss: 1.5417 - val_accuracy: 0.5692 - val_loss: 1.5827 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.4515 - loss: 1.5420
# Epoch 10: val_accuracy did not improve from 0.56923
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 0.4500 - loss: 1.5388 - val_accuracy: 0.5538 - val_loss: 1.6398 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.3511 - loss: 1.9614
# Epoch 11: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 387ms/step - accuracy: 0.3533 - loss: 1.8980 - val_accuracy: 0.5385 - val_loss: 1.6500 - learning_rate: 2.0000e-05
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.4815 - loss: 1.4358
# Epoch 12: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.4810 - loss: 1.4396 - val_accuracy: 0.5385 - val_loss: 1.6676 - learning_rate: 2.0000e-05
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.3281 - loss: 2.1674
# Epoch 13: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 390ms/step - accuracy: 0.3389 - loss: 2.0665 - val_accuracy: 0.5231 - val_loss: 1.6708 - learning_rate: 2.0000e-05
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.4781 - loss: 1.3803
# Epoch 14: val_accuracy did not improve from 0.56923
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 0.4799 - loss: 1.4021 - val_accuracy: 0.5231 - val_loss: 1.6779 - learning_rate: 2.0000e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6570 - loss: 1.2471
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step
#
# ========== Training on Fold 5 ==========
# Found 161 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4465 - loss: 1.9082
# Epoch 1: val_accuracy improved from -inf to 0.44615, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.4271 - loss: 1.9417 - val_accuracy: 0.4462 - val_loss: 1.6328 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.3081 - loss: 1.9977
# Epoch 2: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 352ms/step - accuracy: 0.3049 - loss: 1.9986 - val_accuracy: 0.3385 - val_loss: 1.8157 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.2738 - loss: 2.1383
# Epoch 3: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 390ms/step - accuracy: 0.2755 - loss: 2.1199 - val_accuracy: 0.3692 - val_loss: 1.7815 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.3403 - loss: 1.7166
# Epoch 4: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 335ms/step - accuracy: 0.3449 - loss: 1.7206 - val_accuracy: 0.4308 - val_loss: 1.6523 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.3798 - loss: 2.0119
# Epoch 5: val_accuracy improved from 0.44615 to 0.49231, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 409ms/step - accuracy: 0.3832 - loss: 1.9597 - val_accuracy: 0.4923 - val_loss: 1.5460 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.4956 - loss: 1.3785
# Epoch 6: val_accuracy improved from 0.49231 to 0.56923, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/models/mobilenet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 438ms/step - accuracy: 0.4922 - loss: 1.3936 - val_accuracy: 0.5692 - val_loss: 1.4798 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.4742 - loss: 1.6027
# Epoch 7: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 0.4801 - loss: 1.5818 - val_accuracy: 0.5538 - val_loss: 1.5399 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.5205 - loss: 1.3032
# Epoch 8: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 389ms/step - accuracy: 0.5180 - loss: 1.3056 - val_accuracy: 0.4308 - val_loss: 1.7860 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.4195 - loss: 1.6556
# Epoch 9: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - accuracy: 0.4190 - loss: 1.6447 - val_accuracy: 0.4615 - val_loss: 1.8328 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.5544 - loss: 1.2225
# Epoch 10: val_accuracy did not improve from 0.56923
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - accuracy: 0.5497 - loss: 1.2235 - val_accuracy: 0.4769 - val_loss: 1.9526 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5468 - loss: 1.3432
# Epoch 11: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step - accuracy: 0.5503 - loss: 1.3375 - val_accuracy: 0.4769 - val_loss: 1.9347 - learning_rate: 2.0000e-05
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5313 - loss: 1.2519
# Epoch 12: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 359ms/step - accuracy: 0.5281 - loss: 1.2610 - val_accuracy: 0.4923 - val_loss: 1.9007 - learning_rate: 2.0000e-05
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.5287 - loss: 1.2943
# Epoch 13: val_accuracy did not improve from 0.56923
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 415ms/step - accuracy: 0.5322 - loss: 1.2928 - val_accuracy: 0.5077 - val_loss: 1.8575 - learning_rate: 2.0000e-05
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.4440 - loss: 1.3933
# Epoch 14: val_accuracy did not improve from 0.56923
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 416ms/step - accuracy: 0.4657 - loss: 1.3823 - val_accuracy: 0.5077 - val_loss: 1.8579 - learning_rate: 2.0000e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.5635 - loss: 1.7503
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ✅ All results saved to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/mobilenet/octdl/results/mobilenet_OCTDL_5CV_results.xlsx

# %%
#EfficientNet - OCTDL - 5CV
import os
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Enable mixed precision
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Paths
dataset_base_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/dataset split/OCTDL_Splits"
logs_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/training"
models_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models"
results_path = "/Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/results"

# Make sure directories exist
os.makedirs(logs_path, exist_ok=True)
os.makedirs(models_path, exist_ok=True)
os.makedirs(results_path, exist_ok=True)

# Hyperparameters
image_size = 224
batch_size = 32
epochs = 50
num_classes = 7

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    zoom_range=0.3,
    shear_range=0.2
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Results storage
all_results = []

for i in range(1, 6):
    print(f"\n========== Training on Fold {i} ==========")

    set_path = os.path.join(dataset_base_path, f"OCTDL_Set_{i}")
    train_dir, val_dir, test_dir = [os.path.join(set_path, x) for x in ["Train", "Validation", "Test"]]

    train_data = train_datagen.flow_from_directory(train_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical')
    val_data = val_test_datagen.flow_from_directory(val_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical')
    test_data = val_test_datagen.flow_from_directory(test_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode='categorical', shuffle=False)

    # Compute class weights
    labels = train_data.classes
    unique_classes = np.unique(labels)
    class_weights = compute_class_weight('balanced', classes=unique_classes, y=labels)
    class_weight_dict = {i: weight for i, weight in zip(unique_classes, class_weights)}

    # Load EfficientNetB0
    base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(image_size, image_size, 3))
    
    # Fine-tune top 15 layers
    for layer in base_model.layers[:-15]:
        layer.trainable = False
    for layer in base_model.layers[-15:]:
        layer.trainable = True

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        Dropout(0.5),
        Dense(num_classes, activation="softmax", dtype='float32')
    ])

    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=CategoricalCrossentropy(label_smoothing=0.1),
        metrics=["accuracy"]
    )

    # Callbacks
    model_save_path = os.path.join(models_path, f"efficientnet_OCTDL_best_fold_{i}.keras")
    callbacks = [
        ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, verbose=1),
        EarlyStopping(monitor='val_accuracy', patience=8, verbose=1, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_accuracy', factor=0.2, patience=4, verbose=1),
        CSVLogger(os.path.join(logs_path, f"efficientnet_OCTDL_fold_{i}.csv"), append=True)
    ]

    # Train
    model.fit(train_data, validation_data=val_data, epochs=epochs, class_weight=class_weight_dict, callbacks=callbacks)

    # Evaluate
    test_loss, test_accuracy = model.evaluate(test_data, verbose=1)

    # Predict
    predictions = model.predict(test_data)
    predicted_classes = np.argmax(predictions, axis=1)
    true_labels = test_data.classes

    # Classification report
    report = classification_report(true_labels, predicted_classes, target_names=train_data.class_indices.keys(), output_dict=True)

    all_results.append({
        "Fold": i,
        "Test Accuracy": test_accuracy,
        "Test Loss": test_loss,
        "Precision": report["weighted avg"]["precision"],
        "Recall": report["weighted avg"]["recall"],
        "F1-Score": report["weighted avg"]["f1-score"]
    })

# Save results
results_df = pd.DataFrame(all_results)
results_excel_file = os.path.join(results_path, "efficientnet_OCTDL_5CV_results.xlsx")
results_df.to_excel(results_excel_file, index=False)
print(f"✅ All results saved to {results_excel_file}")
# Out:
# ========== Training on Fold 1 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1864 - loss: 1.9233
# Epoch 1: val_accuracy improved from -inf to 0.50769, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models/efficientnet_OCTDL_best_fold_1.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 6s/step - accuracy: 0.1774 - loss: 1.9387 - val_accuracy: 0.5077 - val_loss: 1.7939 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 790ms/step - accuracy: 0.1991 - loss: 1.6847
# Epoch 2: val_accuracy did not improve from 0.50769
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.1980 - loss: 1.7377 - val_accuracy: 0.5077 - val_loss: 1.7697 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.1645 - loss: 2.2454
# Epoch 3: val_accuracy did not improve from 0.50769
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 956ms/step - accuracy: 0.1666 - loss: 2.1917 - val_accuracy: 0.5077 - val_loss: 1.7541 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.2463 - loss: 1.9809
# Epoch 4: val_accuracy did not improve from 0.50769
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2411 - loss: 1.9753 - val_accuracy: 0.5077 - val_loss: 1.7409 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.2417 - loss: 1.8024
# Epoch 5: val_accuracy did not improve from 0.50769
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2389 - loss: 1.8205 - val_accuracy: 0.5077 - val_loss: 1.7418 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.3094 - loss: 2.1351
# Epoch 6: val_accuracy did not improve from 0.50769
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 873ms/step - accuracy: 0.3032 - loss: 2.1120 - val_accuracy: 0.5077 - val_loss: 1.7416 - learning_rate: 2.0000e-05
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - accuracy: 0.3020 - loss: 1.9391
# Epoch 7: val_accuracy did not improve from 0.50769
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 944ms/step - accuracy: 0.3003 - loss: 1.9429 - val_accuracy: 0.5077 - val_loss: 1.7428 - learning_rate: 2.0000e-05
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.2155 - loss: 1.7714
# Epoch 8: val_accuracy did not improve from 0.50769
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 992ms/step - accuracy: 0.2156 - loss: 1.8018 - val_accuracy: 0.5077 - val_loss: 1.7439 - learning_rate: 2.0000e-05
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 666ms/step - accuracy: 0.2291 - loss: 1.7315
# Epoch 9: val_accuracy did not improve from 0.50769
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 954ms/step - accuracy: 0.2263 - loss: 1.7574 - val_accuracy: 0.5077 - val_loss: 1.7444 - learning_rate: 2.0000e-05
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 466ms/step - accuracy: 0.6013 - loss: 1.7950
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step
#
# ========== Training on Fold 2 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1143 - loss: 1.9485
# Epoch 1: val_accuracy improved from -inf to 0.01538, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models/efficientnet_OCTDL_best_fold_2.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 129s 21s/step - accuracy: 0.1156 - loss: 1.9612 - val_accuracy: 0.0154 - val_loss: 1.9872 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.1574 - loss: 2.1741
# Epoch 2: val_accuracy did not improve from 0.01538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.1552 - loss: 2.1558 - val_accuracy: 0.0154 - val_loss: 1.9800 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.1087 - loss: 2.0795
# Epoch 3: val_accuracy did not improve from 0.01538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 920ms/step - accuracy: 0.1117 - loss: 2.0737 - val_accuracy: 0.0154 - val_loss: 1.9653 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - accuracy: 0.1971 - loss: 2.0109
# Epoch 4: val_accuracy did not improve from 0.01538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 995ms/step - accuracy: 0.1936 - loss: 2.0127 - val_accuracy: 0.0154 - val_loss: 1.9569 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.1547 - loss: 1.7713
# Epoch 5: val_accuracy did not improve from 0.01538
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.1582 - loss: 1.8070 - val_accuracy: 0.0154 - val_loss: 1.9702 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 630ms/step - accuracy: 0.1780 - loss: 1.9807
# Epoch 6: val_accuracy did not improve from 0.01538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 959ms/step - accuracy: 0.1694 - loss: 1.9990 - val_accuracy: 0.0154 - val_loss: 1.9723 - learning_rate: 2.0000e-05
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.1149 - loss: 2.5062
# Epoch 7: val_accuracy did not improve from 0.01538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 904ms/step - accuracy: 0.1161 - loss: 2.4405 - val_accuracy: 0.0154 - val_loss: 1.9729 - learning_rate: 2.0000e-05
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 0.1132 - loss: 2.2068
# Epoch 8: val_accuracy did not improve from 0.01538
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.1147 - loss: 2.1700 - val_accuracy: 0.0154 - val_loss: 1.9715 - learning_rate: 2.0000e-05
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.1605 - loss: 2.6558
# Epoch 9: val_accuracy did not improve from 0.01538
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 990ms/step - accuracy: 0.1587 - loss: 2.5729 - val_accuracy: 0.0154 - val_loss: 1.9699 - learning_rate: 2.0000e-05
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 491ms/step - accuracy: 0.0653 - loss: 1.9975
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step
#
# ========== Training on Fold 3 ==========
# Found 162 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1209 - loss: 1.8733
# Epoch 1: val_accuracy improved from -inf to 0.44615, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models/efficientnet_OCTDL_best_fold_3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 66s 6s/step - accuracy: 0.1230 - loss: 1.8939 - val_accuracy: 0.4462 - val_loss: 1.9163 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.1881 - loss: 2.0513
# Epoch 2: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1903 - loss: 2.0557 - val_accuracy: 0.4462 - val_loss: 1.9212 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.1675 - loss: 2.3730
# Epoch 3: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.1762 - loss: 2.3376 - val_accuracy: 0.4462 - val_loss: 1.9240 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - accuracy: 0.1621 - loss: 1.8096
# Epoch 4: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 956ms/step - accuracy: 0.1575 - loss: 1.8527 - val_accuracy: 0.0462 - val_loss: 1.9267 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.1266 - loss: 1.9913
# Epoch 5: val_accuracy did not improve from 0.44615
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.1314 - loss: 1.9793 - val_accuracy: 0.0462 - val_loss: 1.9400 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.1903 - loss: 1.8614
# Epoch 6: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 958ms/step - accuracy: 0.1834 - loss: 1.8897 - val_accuracy: 0.0462 - val_loss: 1.9436 - learning_rate: 2.0000e-05
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 626ms/step - accuracy: 0.1123 - loss: 1.9550
# Epoch 7: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 907ms/step - accuracy: 0.1112 - loss: 1.9630 - val_accuracy: 0.0462 - val_loss: 1.9479 - learning_rate: 2.0000e-05
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 641ms/step - accuracy: 0.1234 - loss: 2.3652
# Epoch 8: val_accuracy did not improve from 0.44615
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 949ms/step - accuracy: 0.1217 - loss: 2.3161 - val_accuracy: 0.0462 - val_loss: 1.9536 - learning_rate: 2.0000e-05
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.1469 - loss: 2.0395
# Epoch 9: val_accuracy did not improve from 0.44615
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 986ms/step - accuracy: 0.1445 - loss: 2.0467 - val_accuracy: 0.0462 - val_loss: 1.9564 - learning_rate: 2.0000e-05
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 493ms/step - accuracy: 0.7413 - loss: 1.8631
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ========== Training on Fold 4 ==========
# Found 161 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1549 - loss: 2.1525
# Epoch 1: val_accuracy improved from -inf to 0.06154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models/efficientnet_OCTDL_best_fold_4.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.1496 - loss: 2.1461 - val_accuracy: 0.0615 - val_loss: 1.8448 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.1442 - loss: 2.1569
# Epoch 2: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 823ms/step - accuracy: 0.1431 - loss: 2.1426 - val_accuracy: 0.0615 - val_loss: 1.8500 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.2125 - loss: 2.0268
# Epoch 3: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 854ms/step - accuracy: 0.2150 - loss: 2.0199 - val_accuracy: 0.0615 - val_loss: 1.8679 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.2029 - loss: 2.0001
# Epoch 4: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 818ms/step - accuracy: 0.1997 - loss: 2.0053 - val_accuracy: 0.0615 - val_loss: 1.8936 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.1846 - loss: 1.9453
# Epoch 5: val_accuracy did not improve from 0.06154
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 934ms/step - accuracy: 0.1849 - loss: 1.9662 - val_accuracy: 0.0615 - val_loss: 1.9076 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - accuracy: 0.1541 - loss: 1.7659
# Epoch 6: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 963ms/step - accuracy: 0.1596 - loss: 1.7948 - val_accuracy: 0.0615 - val_loss: 1.9158 - learning_rate: 2.0000e-05
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.2556 - loss: 1.9730
# Epoch 7: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 906ms/step - accuracy: 0.2501 - loss: 1.9780 - val_accuracy: 0.0615 - val_loss: 1.9243 - learning_rate: 2.0000e-05
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 700ms/step - accuracy: 0.1967 - loss: 2.0798
# Epoch 8: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.1926 - loss: 2.0790 - val_accuracy: 0.0615 - val_loss: 1.9327 - learning_rate: 2.0000e-05
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.1780 - loss: 2.4214
# Epoch 9: val_accuracy did not improve from 0.06154
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 960ms/step - accuracy: 0.1766 - loss: 2.3656 - val_accuracy: 0.0615 - val_loss: 1.9412 - learning_rate: 2.0000e-05
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step - accuracy: 0.0434 - loss: 1.8370
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step
#
# ========== Training on Fold 5 ==========
# Found 161 images belonging to 7 classes.
# Found 65 images belonging to 7 classes.
# Found 97 images belonging to 7 classes.
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.1473 - loss: 1.9765
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models/efficientnet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 399s 29s/step - accuracy: 0.1502 - loss: 1.9702 - val_accuracy: 0.0000e+00 - val_loss: 2.0618 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1635 - loss: 1.8980
# Epoch 2: val_accuracy did not improve from 0.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.1658 - loss: 1.9070 - val_accuracy: 0.0000e+00 - val_loss: 2.0456 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 911ms/step - accuracy: 0.1990 - loss: 2.3803
# Epoch 3: val_accuracy improved from 0.00000 to 0.03077, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models/efficientnet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1972 - loss: 2.3175 - val_accuracy: 0.0308 - val_loss: 2.0566 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.1698 - loss: 1.9522
# Epoch 4: val_accuracy improved from 0.03077 to 0.06154, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models/efficientnet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.1651 - loss: 1.9521 - val_accuracy: 0.0615 - val_loss: 2.0572 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.1477 - loss: 1.8319
# Epoch 5: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1497 - loss: 1.8416 - val_accuracy: 0.0615 - val_loss: 2.0587 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 767ms/step - accuracy: 0.1575 - loss: 1.9916
# Epoch 6: val_accuracy did not improve from 0.06154
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.1599 - loss: 1.9787 - val_accuracy: 0.0615 - val_loss: 2.0611 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 787ms/step - accuracy: 0.1872 - loss: 1.9174
# Epoch 7: val_accuracy improved from 0.06154 to 0.09231, saving model to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/models/efficientnet_OCTDL_best_fold_5.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1959 - loss: 1.9188 - val_accuracy: 0.0923 - val_loss: 2.0654 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.1905 - loss: 1.9741
# Epoch 8: val_accuracy did not improve from 0.09231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1926 - loss: 1.9645 - val_accuracy: 0.0923 - val_loss: 2.0662 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 776ms/step - accuracy: 0.2493 - loss: 1.9246
# Epoch 9: val_accuracy did not improve from 0.09231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2492 - loss: 1.9212 - val_accuracy: 0.0923 - val_loss: 2.0679 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.3872 - loss: 1.6771
# Epoch 10: val_accuracy did not improve from 0.09231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.3762 - loss: 1.7059 - val_accuracy: 0.0923 - val_loss: 2.0740 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 0.2659 - loss: 1.9209
# Epoch 11: val_accuracy did not improve from 0.09231
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.2661 - loss: 1.9227 - val_accuracy: 0.0923 - val_loss: 2.0968 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 897ms/step - accuracy: 0.2197 - loss: 2.3198
# Epoch 12: val_accuracy did not improve from 0.09231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2291 - loss: 2.2616 - val_accuracy: 0.0615 - val_loss: 2.1063 - learning_rate: 2.0000e-05
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - accuracy: 0.2999 - loss: 1.9369
# Epoch 13: val_accuracy did not improve from 0.09231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2917 - loss: 1.9309 - val_accuracy: 0.0615 - val_loss: 2.1178 - learning_rate: 2.0000e-05
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.2301 - loss: 1.7945
# Epoch 14: val_accuracy did not improve from 0.09231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 998ms/step - accuracy: 0.2300 - loss: 1.8032 - val_accuracy: 0.0615 - val_loss: 2.1281 - learning_rate: 2.0000e-05
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 786ms/step - accuracy: 0.2577 - loss: 2.0361
# Epoch 15: val_accuracy did not improve from 0.09231
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.2564 - loss: 2.0170 - val_accuracy: 0.0615 - val_loss: 2.1382 - learning_rate: 2.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 493ms/step - accuracy: 0.0559 - loss: 2.0142
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/mananmathur/anaconda3/envs/oct_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ✅ All results saved to /Users/mananmathur/Documents/Academics/MIT/subject matter/YEAR 4/SEM 8/PROJECT/project/logs/5CV/efficientnet/octdl/results/efficientnet_OCTDL_5CV_results.xlsx
